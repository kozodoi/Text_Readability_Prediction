# %% [markdown]
# # 1. PARAMETERS

# %%
####### CONFIGURATION

class CFG:

    # environment
    environment  = 'kaggle'  # work environment ['kaggle', 'local']
    device       = 'GPU'    # training device ['GPU', 'TPU']
    device_index = 0        # device index (when using single device)
    num_devices  = 1        # no. GPU/TPU devices (modeling)
    cpu_workers  = 2        # no. CPU cores (data loading)

    # general
    version  = 52     # notebook version (for saving outputs)
    debug    = False  # debug mode runs 10 batches for 3 epochs
    tracking = True   # track results using neptune.ai
    seed     = 10627  # random state

    # data
    num_folds   = 5      # no. CV folds
    num_cuts    = 12     # no. target cuts for stratified split
    num_reps    = 3      # no. repititions of CV
    data_pl     = False  # False or percentage of appended pseudo-labeled data 
    max_len     = 256    # maximum sequence length 
    dynamic_pad = False  # whether to enable dynamic padding on batch level
    
    # augmentations
    p_shuffle   = 0.05  # probability of batch-level sentence shuffle
    noise_alpha = 0     # magnitude of noise in targets based on SD
    p_translate = 0     # probability of swapping a sentence with backtranslation

    # architecture
    backbone       = 'roberta-base'  # transformer backbone   
    hidden_size    = 768             # size of the hidden layer
    pretrained     = True            # pretrained weights [False, True, path]
    freeze_embed   = True            # whether to freeze the embedding layer
    freeze_layers  = 0               # how many deep transformer layers to freeze
    init_range     = None            # weight init range for new layers (None or float)
    hidden_dropout = 0.0             # dropout probability on hidden layers

    # network head
    pooling        = 'mean'  # pooling technique ['default', 'cls', 'mean', 'max', 'meanmax']
    pooling_layer  = -1      # hidden layer to perform pooling
    concat_layers  = 4       # no. concatenated pooling layers starting from pooling_layer
    layer_norm_eps = 1e-7    # layer normalization epsilon
    head_dropout   = 0.0     # dropout probability in head
    
    # training
    num_epochs    = 5      # no. epochs per fold
    batch_size    = 20     # no. images per batch 
    accum_iter    = 1      # no. batches for gradient accumalation
    grad_clip     = False  # max gradient norm (False or float)
    use_fp16      = True   # mixed precision mode 
    max_batches   = False  # max no. batches per training epoch (False or int)
    batch_verbose = False  # print loss every n batches

    # learning rate 
    lr             = 1e-4  # starting learning rate
    decay          = 1e-3  # weight decay of optimizer (L2 regularization)
    lr_layer_decay = 0.85  # LR multiplier when going to deeper layers

    # optimizer & scheduler
    optim           = 'AdamW'   # LR optimizer ['Adam', 'AdamW', 'AdamP', 'madgrad']
    adamw_bias      = True      # AdamW param: whether to enable bias correction
    scheduler       = 'cosine'  # LR scheduler after warmup ['constant', 'linear', 'cosine']
    warmup          = 0.5       # no. epochs for warmup
    update_on_batch = True      # update LR after every batch (or epoch)
    
    # loss function
    loss_fn = 'MSE'  # loss ['MSE', 'RMSE']

    # stochastic weight averaging
    swa               = False     
    swa_start         = 5
    swa_learning_rate = 1e-4
    anneal_epochs     = 3 
    anneal_strategy   = 'cos'
    
    # inference
    eval_step        = 4     # no. batches before evaluation (False or int)
    predict_oof      = True  # whether to produce OOF predictions
    predict_test     = True  # whether to produce test predictions 
    valid_batch_size = 128   # no. cases per batch

# %%
####### CONVERT CONFIGURATION

CFG = dict(vars(CFG))
for key in ['__dict__', '__doc__', '__module__', '__weakref__']:
    del CFG[key]

# %%
####### UPDATES FOR DEBUG MODE

if CFG['debug']:
    CFG['predict_test'] = False
    CFG['tracking']     = False
    CFG['save_all']     = False
    CFG['num_epochs']   = 2
    CFG['num_folds']    = 2

# %% [markdown]
# # 2. PREPARATIONS

# %%
####### PACKAGES

if CFG['environment'] != 'local':
    # !pip install timm transformers accelerate adamp madgrad
    # !pip install --upgrade neptune-client
    # !pip install --upgrade --force-reinstall --no-deps -q kaggle
    
if CFG['device'] == 'TPU':
    # !pip install cloud-tpu-client==0.10 'https://storage.googleapis.com/tpu-pytorch/wheels/torch_xla-1.8-cp37-cp37m-linux_x86_64.whl'

import numpy as np
import pandas as pd

import torch
from torch.utils.data import Dataset, DataLoader

import os
import sys
import time
import pickle

from tqdm.auto import tqdm

from sklearn import metrics
from sklearn.metrics import confusion_matrix, roc_auc_score, mean_squared_error
from sklearn.model_selection import StratifiedKFold, GroupKFold, KFold

from accelerate import notebook_launcher

import warnings
import gc; gc.enable()
# Out:
# Collecting timm
#   Downloading timm-0.4.12-py3-none-any.whl (376 kB)
#      |████████████████████████████████| 376 kB 1.2 MB/s
# Requirement already satisfied: transformers in /opt/conda/lib/python3.7/site-packages (4.2.2)
# Collecting accelerate
#   Downloading accelerate-0.3.0-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 2.8 MB/s
# Collecting adamp
#   Downloading adamp-0.3.0.tar.gz (5.1 kB)
# Collecting madgrad
#   Downloading madgrad-1.1-py3-none-any.whl (7.4 kB)
# Requirement already satisfied: torch>=1.4.0 in /opt/conda/lib/python3.7/site-packages (from accelerate) (1.7.0)
# Requirement already satisfied: pyaml>=20.4.0 in /opt/conda/lib/python3.7/site-packages (from accelerate) (20.4.0)
# Requirement already satisfied: PyYAML in /opt/conda/lib/python3.7/site-packages (from pyaml>=20.4.0->accelerate) (5.3.1)
# Requirement already satisfied: future in /opt/conda/lib/python3.7/site-packages (from torch>=1.4.0->accelerate) (0.18.2)
# Requirement already satisfied: typing_extensions in /opt/conda/lib/python3.7/site-packages (from torch>=1.4.0->accelerate) (3.7.4.3)
# Requirement already satisfied: dataclasses in /opt/conda/lib/python3.7/site-packages (from torch>=1.4.0->accelerate) (0.6)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from torch>=1.4.0->accelerate) (1.19.5)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.7/site-packages (from timm) (0.8.1)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.7/site-packages (from transformers) (3.3.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.7/site-packages (from transformers) (3.0.12)
# Requirement already satisfied: sacremoses in /opt/conda/lib/python3.7/site-packages (from transformers) (0.0.43)
# Requirement already satisfied: tokenizers==0.9.4 in /opt/conda/lib/python3.7/site-packages (from transformers) (0.9.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.7/site-packages (from transformers) (2.25.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.7/site-packages (from transformers) (2020.11.13)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.7/site-packages (from transformers) (4.55.1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.7/site-packages (from transformers) (20.8)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata->transformers) (3.4.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.7/site-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests->transformers) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests->transformers) (1.26.2)
# Requirement already satisfied: click in /opt/conda/lib/python3.7/site-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.7/site-packages (from sacremoses->transformers) (1.0.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: pillow>=4.1.1 in /opt/conda/lib/python3.7/site-packages (from torchvision->timm) (7.2.0)
# Building wheels for collected packages: adamp
# done
#   Created wheel for adamp: filename=adamp-0.3.0-py3-none-any.whl size=5998 sha256=9399507909b420df651837f68113975ceda2ee0013e7a9eaa86b8dcf5f235444
#   Stored in directory: /root/.cache/pip/wheels/bb/95/21/ced2d2cb9944e3a72e58fece7958973eed3fd8d0aeb6e2e450
# Successfully built adamp
# Installing collected packages: timm, madgrad, adamp, accelerate
# Successfully installed accelerate-0.3.0 adamp-0.3.0 madgrad-1.1 timm-0.4.12
# WARNING: You are using pip version 21.0.1; however, version 21.2.1 is available.
# You should consider upgrading via the '/opt/conda/bin/python3.7 -m pip install --upgrade pip' command.
# Collecting neptune-client
#   Downloading neptune-client-0.10.2.tar.gz (243 kB)
#      |████████████████████████████████| 243 kB 1.2 MB/s
# Collecting bravado
#   Downloading bravado-11.0.3-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.7/site-packages (from neptune-client) (7.1.2)
# Requirement already satisfied: future>=0.17.1 in /opt/conda/lib/python3.7/site-packages (from neptune-client) (0.18.2)
# Requirement already satisfied: oauthlib>=2.1.0 in /opt/conda/lib/python3.7/site-packages (from neptune-client) (3.0.1)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.7/site-packages (from neptune-client) (1.1.5)
# Requirement already satisfied: Pillow>=1.1.6 in /opt/conda/lib/python3.7/site-packages (from neptune-client) (7.2.0)
# Requirement already satisfied: PyJWT in /opt/conda/lib/python3.7/site-packages (from neptune-client) (1.7.1)
# Requirement already satisfied: requests>=2.20.0 in /opt/conda/lib/python3.7/site-packages (from neptune-client) (2.25.1)
# Requirement already satisfied: requests-oauthlib>=1.0.0 in /opt/conda/lib/python3.7/site-packages (from neptune-client) (1.3.0)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.7/site-packages (from neptune-client) (1.15.0)
# Requirement already satisfied: websocket-client!=1.0.0,>=0.35.0 in /opt/conda/lib/python3.7/site-packages (from neptune-client) (0.57.0)
# Requirement already satisfied: GitPython>=2.0.8 in /opt/conda/lib/python3.7/site-packages (from neptune-client) (3.1.12)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.7/site-packages (from neptune-client) (20.8)
# Requirement already satisfied: urllib3 in /opt/conda/lib/python3.7/site-packages (from neptune-client) (1.26.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.7/site-packages (from GitPython>=2.0.8->neptune-client) (4.0.5)
# Requirement already satisfied: smmap<4,>=3.0.1 in /opt/conda/lib/python3.7/site-packages (from gitdb<5,>=4.0.1->GitPython>=2.0.8->neptune-client) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests>=2.20.0->neptune-client) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests>=2.20.0->neptune-client) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests>=2.20.0->neptune-client) (2.10)
# Collecting monotonic
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.7/site-packages (from bravado->neptune-client) (3.7.4.3)
# Requirement already satisfied: simplejson in /opt/conda/lib/python3.7/site-packages (from bravado->neptune-client) (3.17.2)
# Requirement already satisfied: python-dateutil in /opt/conda/lib/python3.7/site-packages (from bravado->neptune-client) (2.8.1)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.7/site-packages (from bravado->neptune-client) (5.3.1)
# Requirement already satisfied: msgpack in /opt/conda/lib/python3.7/site-packages (from bravado->neptune-client) (1.0.2)
# Collecting bravado-core>=5.16.1
#   Downloading bravado_core-5.17.0-py2.py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 3.2 MB/s
# Requirement already satisfied: pytz in /opt/conda/lib/python3.7/site-packages (from bravado-core>=5.16.1->bravado->neptune-client) (2020.5)
# Collecting jsonref
#   Downloading jsonref-0.2-py3-none-any.whl (9.3 kB)
# Collecting swagger-spec-validator>=2.0.1
#   Downloading swagger_spec_validator-2.7.3-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: jsonschema[format]>=2.5.1 in /opt/conda/lib/python3.7/site-packages (from bravado-core>=5.16.1->bravado->neptune-client) (3.2.0)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema[format]>=2.5.1->bravado-core>=5.16.1->bravado->neptune-client) (20.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema[format]>=2.5.1->bravado-core>=5.16.1->bravado->neptune-client) (0.17.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.7/site-packages (from jsonschema[format]>=2.5.1->bravado-core>=5.16.1->bravado->neptune-client) (49.6.0.post20201009)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.7/site-packages (from jsonschema[format]>=2.5.1->bravado-core>=5.16.1->bravado->neptune-client) (3.3.0)
# Collecting strict-rfc3339
#   Downloading strict-rfc3339-0.7.tar.gz (17 kB)
# Collecting jsonpointer>1.13
#   Downloading jsonpointer-2.1-py2.py3-none-any.whl (7.4 kB)
# Collecting webcolors
#   Downloading webcolors-1.11.1-py3-none-any.whl (9.9 kB)
# Collecting rfc3987
#   Downloading rfc3987-1.3.8-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata->jsonschema[format]>=2.5.1->bravado-core>=5.16.1->bravado->neptune-client) (3.4.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.7/site-packages (from packaging->neptune-client) (2.4.7)
# Requirement already satisfied: numpy>=1.15.4 in /opt/conda/lib/python3.7/site-packages (from pandas->neptune-client) (1.19.5)
# Building wheels for collected packages: neptune-client, strict-rfc3339
# done
#   Created wheel for neptune-client: filename=neptune_client-0.10.2-py2.py3-none-any.whl size=424890 sha256=e8a5007a95df54b843c44ebee7d9d1592f8630f9f1297ee6d81686cdf3d107eb
#   Stored in directory: /root/.cache/pip/wheels/e9/ac/d7/15fa2be10dc2b4aee3d51d94e3ad1a62ae11642ae7a51f571a
# done
#   Created wheel for strict-rfc3339: filename=strict_rfc3339-0.7-py3-none-any.whl size=18119 sha256=acbf0ad3f313465bd9f616cef69b0c3bbcdbb9074a30cc1be7d2966f1cf5c9d8
#   Stored in directory: /root/.cache/pip/wheels/f3/1d/9f/2a74caecb81b8beb9a4fbe1754203d4b7cf42ef5d39e0d2311
# Successfully built neptune-client strict-rfc3339
# Installing collected packages: webcolors, strict-rfc3339, rfc3987, jsonpointer, swagger-spec-validator, jsonref, monotonic, bravado-core, bravado, neptune-client
# Successfully installed bravado-11.0.3 bravado-core-5.17.0 jsonpointer-2.1 jsonref-0.2 monotonic-1.6 neptune-client-0.10.2 rfc3987-1.3.8 strict-rfc3339-0.7 swagger-spec-validator-2.7.3 webcolors-1.11.1
# WARNING: You are using pip version 21.0.1; however, version 21.2.1 is available.
# You should consider upgrading via the '/opt/conda/bin/python3.7 -m pip install --upgrade pip' command.
# WARNING: You are using pip version 21.0.1; however, version 21.2.1 is available.
# You should consider upgrading via the '/opt/conda/bin/python3.7 -m pip install --upgrade pip' command.

# %%
####### MODULES

# source
if CFG['environment'] == 'local':
    sys.path.append('../code')  
elif CFG['environment'] == 'kaggle':
    sys.path.append('../input/readability-code')  

# utilities
from utilities import *

# training and inference
from run_training import run_training
from run_inference import run_inference

# visualiztion
from sample_batch import sample_batch

# %%
####### WORKING PATHS

if CFG['environment'] == 'local':
    CFG['data_path']  = '../input/'
    CFG['out_path']   = '../output/v' + str(CFG['version']) + '/'
    if not os.path.exists(CFG['out_path']):
        os.mkdir(CFG['out_path'])
        
elif CFG['environment'] == 'kaggle':
    CFG['data_path']  = '../input/commonlitreadabilityprize/'
    CFG['out_path']   = ''

# %%
####### TRACKING WITH NEPTUNE

if CFG['tracking']:
    import neptune 
    neptune.init(api_token = 'you-api-token',
                 project_qualified_name = 'your-project')
    neptune.create_experiment(name = 'v' + str(CFG['version']), params = CFG)
# Out:
# https://app.neptune.ai/ml_comps/readability/e/READ-427

# %%
####### SETTINGS

warnings.filterwarnings('ignore')       # ignoring warnings
pd.options.display.max_columns = 100    # maximum displayed columns
torch.backends.cudnn.benchmark = False  # set to True if NN inputs are the same size
seed_everything(CFG['seed'])            # random seed
# Out:
# - setting random seed to 10627...

# %% [markdown]
# # 3. DATA PREP

# %%
####### TRAIN DATA PROCESSING

# import
df = pd.read_csv(CFG['data_path'] + 'train.csv')

# check max length
from tokenizer import get_tokenizer
tokenizer = get_tokenizer(CFG)
df['seq_length'] = df['excerpt'].apply(lambda x: len(tokenizer(x)['input_ids']))
print('maximum length: {}'.format(max(df['seq_length'])))

# partitioning
df['target_cat'] = pd.cut(df['target'], CFG['num_cuts'], labels = False)
for i in range(CFG['num_reps']):
    folds = StratifiedKFold(n_splits = CFG['num_folds'], shuffle = True, random_state = CFG['seed'] - i)
    for fold_idx, (trn_idx, val_idx) in enumerate(folds.split(df, df['target_cat'])):
        df.loc[val_idx, 'fold' + str(i)] = int(fold_idx)
    df['fold' + str(i)] = df['fold' + str(i)].astype(int)
             
# display
print('train shape: {}'.format(df.shape))
display(df.head())
# Out:
# Downloading:   0%|          | 0.00/481 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# maximum length: 322
# train shape: (2834, 11)
#           id url_legal license  \
# 0  c12129c31       NaN     NaN
# 1  85aa80a4c       NaN     NaN
# 2  b69ac6792       NaN     NaN
# 3  dd1000b26       NaN     NaN
# 4  37c1b32fb       NaN     NaN
#
#                                              excerpt    target  \
# 0  When the young people returned to the ballroom... -0.340259
# 1  All through dinner time, Mrs. Fayre was somewh... -0.315372
# 2  As Roger had predicted, the snow departed as q... -0.580118
# 3  And outside before the palace a great garden w... -1.054013
# 4  Once upon a time there were Three Bears who li...  0.247197
#
#    standard_error  seq_length  target_cat  fold0  fold1  fold2
# 0        0.464009         227           7      1      3      1
# 1        0.480805         238           7      0      3      1
# 2        0.476676         225           6      4      0      3
# 3        0.450007         224           5      3      2      0
# 4        0.510845         186           8      1      2      2

# %%
####### BACKTRANSLATION AUGMENTATION

# path
if CFG['environment'] == 'local':
    trans_path = CFG['data_path']
elif CFG['environment'] == 'kaggle':
    trans_path = '/kaggle/input/readability-data/'

# import
df_de = pd.read_csv(trans_path + 'train_de_en.csv')
df_es = pd.read_csv(trans_path + 'train_es_en.csv')
df_fr = pd.read_csv(trans_path + 'train_fr_en.csv')
df_it = pd.read_csv(trans_path + 'train_it_en.csv')
df_pt = pd.read_csv(trans_path + 'train_pt_en.csv')
df_ru = pd.read_csv(trans_path + 'train_ru_en.csv')
df_tr = pd.read_csv(trans_path + 'train_tr_en.csv')

# merge data
df['excerpt_de_en'] = df_de['excerpt_de_en']
df['excerpt_es_en'] = df_es['excerpt_es_en']
df['excerpt_fr_en'] = df_fr['excerpt_fr_en']
df['excerpt_it_en'] = df_it['excerpt_it_en']
df['excerpt_pt_en'] = df_pt['excerpt_pt_en']
df['excerpt_ru_en'] = df_ru['excerpt_ru_en']
df['excerpt_tr_en'] = df_tr['excerpt_tr_en']

# clear memory
del df_de, df_es, df_fr, df_it, df_pt, df_ru, df_tr

# display
print('train shape: {}'.format(df.shape))
df.head()
# Out:
# train shape: (2834, 18)
#           id url_legal license  \
# 0  c12129c31       NaN     NaN
# 1  85aa80a4c       NaN     NaN
# 2  b69ac6792       NaN     NaN
# 3  dd1000b26       NaN     NaN
# 4  37c1b32fb       NaN     NaN
#
#                                              excerpt    target  \
# 0  When the young people returned to the ballroom... -0.340259
# 1  All through dinner time, Mrs. Fayre was somewh... -0.315372
# 2  As Roger had predicted, the snow departed as q... -0.580118
# 3  And outside before the palace a great garden w... -1.054013
# 4  Once upon a time there were Three Bears who li...  0.247197
#
#    standard_error  seq_length  target_cat  fold0  fold1  fold2  \
# 0        0.464009         227           7      1      3      1
# 1        0.480805         238           7      0      3      1
# 2        0.476676         225           6      4      0      3
# 3        0.450007         224           5      3      2      0
# 4        0.510845         186           8      1      2      2
#
#                                        excerpt_de_en  \
# 0  When the young people returned to the ballroom...
# 1  Mrs. Fayre was a little quiet throughout dinne...
# 2  As Roger had predicted, the snow was clearing ...
# 3  And outside the palace was a large walled gard...
# 4  Once upon a time there were three bears who li...
#
#                                        excerpt_es_en  \
# 0  When the young men returned to the ballroom, h...
# 1  Throughout the entire dinner, Mrs. Fayre was s...
# 2  As Roger had predicted, the snow was gone as f...
# 3  And outside, in front of the palace, was a lar...
# 4  Once upon a time, there were Three Bears who l...
#
#                                        excerpt_fr_en  \
# 0  When the young people returned to the ballroom...
# 1  Throughout the dinner hour, Mrs. Fayre was som...
# 2  As Roger predicted, the snow went away as quic...
# 3  And outside, in front of the palace, a large g...
# 4  Once upon a time there were three bears who li...
#
#                                        excerpt_it_en  \
# 0  When the youngsters returned to the ballroom, ...
# 1  Throughout the dinner hour, Mrs. Fayre remaine...
# 2  As Roger had predicted, the snow was gone as f...
# 3  And outside, in front of the palace, a large g...
# 4  Once upon a time there were three bears who li...
#
#                                        excerpt_pt_en  \
# 0  When the young men returned to the ballroom, h...
# 1  All through dinner Mrs Fayre was somewhat sile...
# 2  As Roger had predicted, the snow disappeared a...
# 3  And outside, in front of the palace, a large g...
# 4  Once upon a time there were three bears who li...
#
#                                        excerpt_ru_en  \
# 0  When the young people returned to the ballroom...
# 1  Throughout dinner Mrs. Fair remained silent, l...
# 2  As Roger had predicted, the snow went away as ...
# 3  And outside, in front of the palace, a large g...
# 4  Once upon a time there were three bears who li...
#
#                                        excerpt_tr_en
# 0  When the teens returned to the ballroom, she p...
# 1  During mealtime, Miss Fayre was somewhat quiet...
# 2  As Roger predicted, the snow parted as quickly...
# 3  And outside, in front of the palace, was a gre...
# 4  Once upon a time there were Three Bears who li...

# %%
####### TEST DATA PROCESSING

# import
sub = pd.read_csv(CFG['data_path'] + 'test.csv')

# subset if debug
if CFG['debug']:
    sub = sub.head(CFG['valid_batch_size'])

# display
print('test shape: {}'.format(sub.shape))
display(sub.head())
# Out:
# test shape: (7, 4)
#           id                                    url_legal       license  \
# 0  c0f722661                                          NaN           NaN
# 1  f0953f0a5                                          NaN           NaN
# 2  0df072751                                          NaN           NaN
# 3  04caf4e0c  https://en.wikipedia.org/wiki/Cell_division  CC BY-SA 3.0
# 4  0e63f8bea      https://en.wikipedia.org/wiki/Debugging  CC BY-SA 3.0
#
#                                              excerpt
# 0  My hope lay in Jack's promise that he would ke...
# 1  Dotty continued to go to Mrs. Gray's every nig...
# 2  It was a bright and cheerful scene that greete...
# 3  Cell division is the process by which a parent...
# 4  Debugging is the process of finding and resolv...

# %%
###### SHOW SAMPLE BATCH

_ = sample_batch(CFG, df, sample_size = 5, seq_size = 15, batch_idx = 2)
# Out:
# - setting random seed to 10627...
# - loading time: 0.0724 vs 0.0484 seconds
# - inputs shape: torch.Size([5, 256]) vs torch.Size([5, 256])
# ----------------------------------------------------------------------------------------------------
# 0, 250, 5973, 2060, 1023, 3760, 21, 1613, 6, 29396, 21, 1613, 4, 20, 929    |           -3.081337118
# 0, 243, 21, 2047, 30, 5, 5402, 604, 9, 2240, 14, 7765, 12749, 18, 19023     |           -2.145248365
# 0, 133, 6700, 11, 10, 3027, 2352, 2322, 5, 1946, 9, 80, 4, 20, 32           |           -1.400318025
# 0, 133, 31918, 3203, 40968, 62, 8, 159, 5, 251, 6, 614, 12, 1755, 6691      |           -0.495298635
# 0, 713, 10829, 338, 1512, 281, 21, 39676, 12, 7109, 107, 793, 4, 91, 21     |    0.24580570899999998
# ----------------------------------------------------------------------------------------------------
# <s>It was believed by the principal men of Virginia that Talbot's sympath   |           -3.081337118
# <s>This Pedrarias was seventy-two years old. He was                         |           -2.145248365
# <s>The Emperor walked nervously up and down the long, low-ceiled            |           -1.400318025
# <s>The clock in a nearby church struck the hour of two. The are             |           -0.495298635
# <s>Aunt Abigail was gone, Eleanor was gone. The room                        |    0.24580570899999998
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# # 4. CROSS-VALIDATION

# %%
####### CROSS-VALIDATION LOOP

# timer
cv_start = time.time()

# run cross-validation
print('-' * 55)
notebook_launcher(function      = run_training,
                  args          = (df, CFG),
                  num_processes = CFG['num_devices'],
                  use_fp16      = CFG['use_fp16'])

# clear memory
gc.collect()
torch.cuda.empty_cache()

# feedback
print('')
print('Finished in {:.2f} minutes'.format((time.time() - cv_start) / 60))
# Out:
# -------------------------------------------------------
# Launching training on one GPU.
# -------------------------------------------------------
# REP 1/3 | FOLD 1/5
# -------------------------------------------------------
# Downloading:   0%|          | 0.00/501M [00:00<?, ?B/s]
# - no. observations: train - 2267, valid - 567
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 1/5 | lr = 0.000971 | trn_loss = 1.0207 | val_loss = 0.2928 | val_score = 0.5411 | 3.81 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 2/5 | lr = 0.000753 | trn_loss = 0.2326 | val_loss = 0.2469 | val_score = 0.4969 | 3.85 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 3/5 | lr = 0.000416 | trn_loss = 0.1165 | val_loss = 0.2347 | val_score = 0.4845 | 3.73 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 4/5 | lr = 0.000119 | trn_loss = 0.0573 | val_loss = 0.2316 | val_score = 0.4813 | 3.63 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 5/5 | lr = 0.000000 | trn_loss = 0.0358 | val_loss = 0.2389 | val_score = 0.4888 | 3.60 min
# -------------------------------------------------------
# Best: score = 0.4813 (epoch 4)
# -------------------------------------------------------
# -------------------------------------------------------
# REP 1/3 | FOLD 2/5
# -------------------------------------------------------
# - no. observations: train - 2267, valid - 567
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 1/5 | lr = 0.000971 | trn_loss = 0.5659 | val_loss = 0.2686 | val_score = 0.5183 | 3.97 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 2/5 | lr = 0.000753 | trn_loss = 0.2583 | val_loss = 0.2359 | val_score = 0.4857 | 3.72 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 3/5 | lr = 0.000416 | trn_loss = 0.1336 | val_loss = 0.2131 | val_score = 0.4616 | 3.72 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 4/5 | lr = 0.000119 | trn_loss = 0.0613 | val_loss = 0.2148 | val_score = 0.4634 | 3.62 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 5/5 | lr = 0.000000 | trn_loss = 0.0387 | val_loss = 0.2165 | val_score = 0.4653 | 3.61 min
# -------------------------------------------------------
# Best: score = 0.4616 (epoch 3)
# -------------------------------------------------------
# -------------------------------------------------------
# REP 1/3 | FOLD 3/5
# -------------------------------------------------------
# - no. observations: train - 2267, valid - 567
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 1/5 | lr = 0.000971 | trn_loss = 0.6884 | val_loss = 0.3398 | val_score = 0.5829 | 3.82 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 2/5 | lr = 0.000753 | trn_loss = 0.2442 | val_loss = 0.2328 | val_score = 0.4825 | 3.83 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 3/5 | lr = 0.000416 | trn_loss = 0.1356 | val_loss = 0.2303 | val_score = 0.4799 | 3.68 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 4/5 | lr = 0.000119 | trn_loss = 0.0604 | val_loss = 0.2249 | val_score = 0.4743 | 3.73 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 5/5 | lr = 0.000000 | trn_loss = 0.0394 | val_loss = 0.2304 | val_score = 0.4800 | 3.61 min
# -------------------------------------------------------
# Best: score = 0.4743 (epoch 4)
# -------------------------------------------------------
# -------------------------------------------------------
# REP 1/3 | FOLD 4/5
# -------------------------------------------------------
# - no. observations: train - 2267, valid - 567
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 1/5 | lr = 0.000971 | trn_loss = 0.8457 | val_loss = 0.3423 | val_score = 0.5851 | 3.87 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 2/5 | lr = 0.000753 | trn_loss = 0.2630 | val_loss = 0.2589 | val_score = 0.5088 | 3.75 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 3/5 | lr = 0.000416 | trn_loss = 0.1281 | val_loss = 0.2422 | val_score = 0.4922 | 3.76 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 4/5 | lr = 0.000119 | trn_loss = 0.0672 | val_loss = 0.2434 | val_score = 0.4933 | 3.61 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 5/5 | lr = 0.000000 | trn_loss = 0.0422 | val_loss = 0.2444 | val_score = 0.4943 | 3.62 min
# -------------------------------------------------------
# Best: score = 0.4922 (epoch 3)
# -------------------------------------------------------
# -------------------------------------------------------
# REP 1/3 | FOLD 5/5
# -------------------------------------------------------
# - no. observations: train - 2268, valid - 566
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 1/5 | lr = 0.000971 | trn_loss = 0.5842 | val_loss = 0.3041 | val_score = 0.5514 | 4.00 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 2/5 | lr = 0.000753 | trn_loss = 0.2252 | val_loss = 0.2399 | val_score = 0.4898 | 3.92 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 3/5 | lr = 0.000416 | trn_loss = 0.1150 | val_loss = 0.2293 | val_score = 0.4789 | 3.73 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 4/5 | lr = 0.000119 | trn_loss = 0.0552 | val_loss = 0.2220 | val_score = 0.4711 | 3.70 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 5/5 | lr = 0.000000 | trn_loss = 0.0340 | val_loss = 0.2241 | val_score = 0.4734 | 3.61 min
# -------------------------------------------------------
# Best: score = 0.4711 (epoch 4)
# -------------------------------------------------------
# -------------------------------------------------------
# REP 1/3 | OOF score = 0.4761
# -------------------------------------------------------
#
# -------------------------------------------------------
# REP 2/3 | FOLD 1/5
# -------------------------------------------------------
# - no. observations: train - 2267, valid - 567
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 1/5 | lr = 0.000971 | trn_loss = 0.9846 | val_loss = 0.2865 | val_score = 0.5353 | 3.92 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 2/5 | lr = 0.000753 | trn_loss = 0.2435 | val_loss = 0.2413 | val_score = 0.4912 | 3.84 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 3/5 | lr = 0.000416 | trn_loss = 0.1520 | val_loss = 0.2345 | val_score = 0.4842 | 3.71 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 4/5 | lr = 0.000119 | trn_loss = 0.0689 | val_loss = 0.2341 | val_score = 0.4838 | 3.65 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 5/5 | lr = 0.000000 | trn_loss = 0.0429 | val_loss = 0.2346 | val_score = 0.4844 | 3.62 min
# -------------------------------------------------------
# Best: score = 0.4838 (epoch 4)
# -------------------------------------------------------
# -------------------------------------------------------
# REP 2/3 | FOLD 2/5
# -------------------------------------------------------
# - no. observations: train - 2267, valid - 567
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 1/5 | lr = 0.000971 | trn_loss = 0.5611 | val_loss = 0.3033 | val_score = 0.5507 | 4.00 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 2/5 | lr = 0.000753 | trn_loss = 0.2280 | val_loss = 0.2504 | val_score = 0.5004 | 3.87 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 3/5 | lr = 0.000416 | trn_loss = 0.1068 | val_loss = 0.2330 | val_score = 0.4827 | 3.75 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 4/5 | lr = 0.000119 | trn_loss = 0.0564 | val_loss = 0.2362 | val_score = 0.4860 | 3.62 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 5/5 | lr = 0.000000 | trn_loss = 0.0341 | val_loss = 0.2370 | val_score = 0.4868 | 3.63 min
# -------------------------------------------------------
# Best: score = 0.4827 (epoch 3)
# -------------------------------------------------------
# -------------------------------------------------------
# REP 2/3 | FOLD 3/5
# -------------------------------------------------------
# - no. observations: train - 2267, valid - 567
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 1/5 | lr = 0.000971 | trn_loss = 0.5604 | val_loss = 0.2862 | val_score = 0.5350 | 3.95 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 2/5 | lr = 0.000753 | trn_loss = 0.2244 | val_loss = 0.2228 | val_score = 0.4720 | 3.81 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 3/5 | lr = 0.000416 | trn_loss = 0.1131 | val_loss = 0.2093 | val_score = 0.4575 | 3.67 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 4/5 | lr = 0.000119 | trn_loss = 0.0521 | val_loss = 0.2165 | val_score = 0.4653 | 3.63 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 5/5 | lr = 0.000000 | trn_loss = 0.0350 | val_loss = 0.2243 | val_score = 0.4736 | 3.62 min
# -------------------------------------------------------
# Best: score = 0.4575 (epoch 3)
# -------------------------------------------------------
# -------------------------------------------------------
# REP 2/3 | FOLD 4/5
# -------------------------------------------------------
# - no. observations: train - 2267, valid - 567
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 1/5 | lr = 0.000971 | trn_loss = 0.8268 | val_loss = 0.2961 | val_score = 0.5441 | 3.98 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 2/5 | lr = 0.000753 | trn_loss = 0.2432 | val_loss = 0.2457 | val_score = 0.4957 | 3.70 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 3/5 | lr = 0.000416 | trn_loss = 0.1335 | val_loss = 0.2350 | val_score = 0.4847 | 3.71 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 4/5 | lr = 0.000119 | trn_loss = 0.0684 | val_loss = 0.2332 | val_score = 0.4829 | 3.69 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 5/5 | lr = 0.000000 | trn_loss = 0.0431 | val_loss = 0.2347 | val_score = 0.4845 | 3.62 min
# -------------------------------------------------------
# Best: score = 0.4829 (epoch 4)
# -------------------------------------------------------
# -------------------------------------------------------
# REP 2/3 | FOLD 5/5
# -------------------------------------------------------
# - no. observations: train - 2268, valid - 566
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 1/5 | lr = 0.000971 | trn_loss = 0.6301 | val_loss = 0.2810 | val_score = 0.5301 | 3.92 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 2/5 | lr = 0.000753 | trn_loss = 0.2286 | val_loss = 0.2395 | val_score = 0.4894 | 3.76 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 3/5 | lr = 0.000416 | trn_loss = 0.1197 | val_loss = 0.2196 | val_score = 0.4686 | 3.75 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 4/5 | lr = 0.000119 | trn_loss = 0.0527 | val_loss = 0.2200 | val_score = 0.4691 | 3.62 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 5/5 | lr = 0.000000 | trn_loss = 0.0348 | val_loss = 0.2181 | val_score = 0.4670 | 3.68 min
# -------------------------------------------------------
# Best: score = 0.4670 (epoch 5)
# -------------------------------------------------------
# -------------------------------------------------------
# REP 2/3 | OOF score = 0.4748
# -------------------------------------------------------
#
# -------------------------------------------------------
# REP 3/3 | FOLD 1/5
# -------------------------------------------------------
# - no. observations: train - 2267, valid - 567
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 1/5 | lr = 0.000971 | trn_loss = 0.9770 | val_loss = 0.3370 | val_score = 0.5805 | 3.90 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 2/5 | lr = 0.000753 | trn_loss = 0.2687 | val_loss = 0.2466 | val_score = 0.4966 | 3.85 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 3/5 | lr = 0.000416 | trn_loss = 0.1490 | val_loss = 0.2286 | val_score = 0.4781 | 3.79 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 4/5 | lr = 0.000119 | trn_loss = 0.0791 | val_loss = 0.2222 | val_score = 0.4713 | 3.73 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 5/5 | lr = 0.000000 | trn_loss = 0.0499 | val_loss = 0.2274 | val_score = 0.4769 | 3.63 min
# -------------------------------------------------------
# Best: score = 0.4713 (epoch 4)
# -------------------------------------------------------
# -------------------------------------------------------
# REP 3/3 | FOLD 2/5
# -------------------------------------------------------
# - no. observations: train - 2267, valid - 567
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 1/5 | lr = 0.000971 | trn_loss = 0.5376 | val_loss = 0.2904 | val_score = 0.5389 | 3.94 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 2/5 | lr = 0.000753 | trn_loss = 0.2423 | val_loss = 0.2275 | val_score = 0.4770 | 3.87 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 3/5 | lr = 0.000416 | trn_loss = 0.1211 | val_loss = 0.2253 | val_score = 0.4746 | 3.65 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 4/5 | lr = 0.000119 | trn_loss = 0.0585 | val_loss = 0.2301 | val_score = 0.4797 | 3.62 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 5/5 | lr = 0.000000 | trn_loss = 0.0367 | val_loss = 0.2302 | val_score = 0.4798 | 3.62 min
# -------------------------------------------------------
# Best: score = 0.4746 (epoch 3)
# -------------------------------------------------------
# -------------------------------------------------------
# REP 3/3 | FOLD 3/5
# -------------------------------------------------------
# - no. observations: train - 2267, valid - 567
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 1/5 | lr = 0.000971 | trn_loss = 0.6076 | val_loss = 0.2859 | val_score = 0.5347 | 4.05 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 2/5 | lr = 0.000753 | trn_loss = 0.2583 | val_loss = 0.2306 | val_score = 0.4802 | 3.74 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 3/5 | lr = 0.000416 | trn_loss = 0.1240 | val_loss = 0.2225 | val_score = 0.4717 | 3.71 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 4/5 | lr = 0.000119 | trn_loss = 0.0668 | val_loss = 0.2177 | val_score = 0.4666 | 3.71 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 5/5 | lr = 0.000000 | trn_loss = 0.0439 | val_loss = 0.2182 | val_score = 0.4671 | 3.63 min
# -------------------------------------------------------
# Best: score = 0.4666 (epoch 4)
# -------------------------------------------------------
# -------------------------------------------------------
# REP 3/3 | FOLD 4/5
# -------------------------------------------------------
# - no. observations: train - 2267, valid - 567
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 1/5 | lr = 0.000971 | trn_loss = 0.8156 | val_loss = 0.3078 | val_score = 0.5548 | 3.92 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 2/5 | lr = 0.000753 | trn_loss = 0.2482 | val_loss = 0.2445 | val_score = 0.4945 | 3.76 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 3/5 | lr = 0.000416 | trn_loss = 0.1256 | val_loss = 0.2323 | val_score = 0.4819 | 3.78 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 4/5 | lr = 0.000119 | trn_loss = 0.0638 | val_loss = 0.2348 | val_score = 0.4846 | 3.63 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 5/5 | lr = 0.000000 | trn_loss = 0.0417 | val_loss = 0.2336 | val_score = 0.4833 | 3.62 min
# -------------------------------------------------------
# Best: score = 0.4819 (epoch 3)
# -------------------------------------------------------
# -------------------------------------------------------
# REP 3/3 | FOLD 5/5
# -------------------------------------------------------
# - no. observations: train - 2268, valid - 566
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 1/5 | lr = 0.000971 | trn_loss = 0.6099 | val_loss = 0.3151 | val_score = 0.5614 | 3.93 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 2/5 | lr = 0.000753 | trn_loss = 0.2305 | val_loss = 0.2385 | val_score = 0.4884 | 3.82 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 3/5 | lr = 0.000416 | trn_loss = 0.1202 | val_loss = 0.2323 | val_score = 0.4820 | 3.69 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 4/5 | lr = 0.000119 | trn_loss = 0.0571 | val_loss = 0.2253 | val_score = 0.4747 | 3.77 min
#   0%|          | 0/114 [00:00<?, ?it/s]
# -- epoch 5/5 | lr = 0.000000 | trn_loss = 0.0366 | val_loss = 0.2253 | val_score = 0.4747 | 3.62 min
# -------------------------------------------------------
# Best: score = 0.4747 (epoch 4)
# -------------------------------------------------------
# -------------------------------------------------------
# REP 3/3 | OOF score = 0.4738
# -------------------------------------------------------
#
# -------------------------------------------------------
# Mean OOF score = 0.4749
# -------------------------------------------------------
#
# Finished in 283.32 minutes

# %% [markdown]
# # 5. INFERENCE

# %%
####### INFERENCE LOOP

# timer
cv_start = time.time()

# run cross-validation
print('-' * 55)
notebook_launcher(function      = run_inference,
                  args          = (df, sub, CFG),
                  num_processes = 1,
                  use_fp16      = CFG['use_fp16'])

# clear memory
gc.collect()
torch.cuda.empty_cache()

# feedback
print('')
print('Finished in {:.2f} minutes'.format((time.time() - cv_start) / 60))
# Out:
# -------------------------------------------------------
# Launching training on one GPU.
# -------------------------------------------------------
# REP 1/3 | FOLD 1/5
# -------------------------------------------------------
# -- loaded custom weights
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# -------------------------------------------------------
# REP 1/3 | FOLD 2/5
# -------------------------------------------------------
# -- loaded custom weights
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# -------------------------------------------------------
# REP 1/3 | FOLD 3/5
# -------------------------------------------------------
# -- loaded custom weights
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# -------------------------------------------------------
# REP 1/3 | FOLD 4/5
# -------------------------------------------------------
# -- loaded custom weights
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# -------------------------------------------------------
# REP 1/3 | FOLD 5/5
# -------------------------------------------------------
# -- loaded custom weights
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# -------------------------------------------------------
# REP 2/3 | FOLD 1/5
# -------------------------------------------------------
# -- loaded custom weights
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# -------------------------------------------------------
# REP 2/3 | FOLD 2/5
# -------------------------------------------------------
# -- loaded custom weights
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# -------------------------------------------------------
# REP 2/3 | FOLD 3/5
# -------------------------------------------------------
# -- loaded custom weights
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# -------------------------------------------------------
# REP 2/3 | FOLD 4/5
# -------------------------------------------------------
# -- loaded custom weights
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# -------------------------------------------------------
# REP 2/3 | FOLD 5/5
# -------------------------------------------------------
# -- loaded custom weights
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# -------------------------------------------------------
# REP 3/3 | FOLD 1/5
# -------------------------------------------------------
# -- loaded custom weights
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# -------------------------------------------------------
# REP 3/3 | FOLD 2/5
# -------------------------------------------------------
# -- loaded custom weights
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# -------------------------------------------------------
# REP 3/3 | FOLD 3/5
# -------------------------------------------------------
# -- loaded custom weights
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# -------------------------------------------------------
# REP 3/3 | FOLD 4/5
# -------------------------------------------------------
# -- loaded custom weights
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# -------------------------------------------------------
# REP 3/3 | FOLD 5/5
# -------------------------------------------------------
# -- loaded custom weights
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Finished in 3.89 minutes

# %%
####### CHECK OOF PERFORMANCE

# import OOF
oof = pd.read_csv(CFG['out_path'] + 'oof.csv')

# compute score
oof_score = []
for rep in range(CFG['num_reps']):
    oof_score.append(get_score(oof['target'], oof['pred_rep' + str(rep)]))
CFG['oof_score'] = np.mean(oof_score)

# compute bag score
blend = 'amean'
oof['blend']     = compute_blend(oof, ['pred_rep' + str(rep) for rep in range(CFG['num_reps'])], blend, CFG)
CFG['bag_score'] = get_score(oof['target'], oof['blend'])

# print performance
print('-' * 22)
print('OOF score     = {:.4f}'.format(CFG['oof_score']))
print('OOF bag score = {:.4f}'.format(CFG['bag_score']))
print('-' * 22)
# Out:
# ----------------------
# OOF score     = 0.4750
# OOF bag score = 0.4672
# ----------------------

# %%
####### EXPORT CONFIGURATION

# save dictionary
pickle.dump(CFG, open(CFG['out_path'] + 'configuration.pkl', 'wb'))

# send data to Neptune
if CFG['tracking']:
    neptune.send_metric('oof_score', CFG['oof_score'])
    neptune.send_metric('bag_score', CFG['bag_score'])
    neptune.send_artifact(CFG['out_path'] + 'configuration.pkl')
    neptune.stop()
